# %%
import numpy as np

# %%
np.random.rand(3,0)
# Out:
# array([], shape=(3, 0), dtype=float64)

# %% [raw]
# np.random.rand(3,0) * np.random.rand(0,3)

# %% [raw]
# ValueError: operands could not be broadcast together with shapes (3,0) (0,3)

# %%
np.random.rand(3,0) @ np.random.rand(0,3)
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
