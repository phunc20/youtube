# %% [markdown]
# # `tarfile`

# %%
import tarfile

# %%
# %cd ~/corbeille/
# Out:
# /home/phunc20/corbeille

# %%
ls
# Out:
# 01_cats_and_dogs.jl          homl-2e.pdf*                         train.tar.bz2
# dollar.sh*                   julia-1.5.1-linux-x86_64.tar.gz      val.tar.bz2
# dsp--prandoni-vetterli.pdf*  julia-1.5.1-linux-x86_64.tar.gz.asc
# ez_dwmbar*                   test.tar.bz2

# %%
test_tarfile = tarfile.open("test.tar.bz2")

# %%
test_tarfile.list()
# Out:
# ?rwxr-xr-x phunc20/wheel          0 2020-09-29 14:48:35 test/
# ?rwxr-xr-x phunc20/wheel          0 2020-09-29 16:05:47 test/co/
# ?rw-r--r-- phunc20/wheel      49588 2020-09-29 15:56:57 test/co/co-5586-T7-03991.jpg
# ?rw-r--r-- phunc20/wheel      50942 2020-09-29 15:57:01 test/co/co-5586-T7-06860.jpg
# ?rw-r--r-- phunc20/wheel      22964 2020-09-29 16:05:45 test/co/co-5586-T6-09217.jpg
# ?rw-r--r-- phunc20/wheel      49475 2020-09-29 15:57:06 test/co/co-5586-T7-09832.jpg
# ?rw-r--r-- phunc20/wheel       9449 2020-09-29 16:03:39 test/co/co-5586-T5-03914.jpg
# ?rw-r--r-- phunc20/wheel      54597 2020-09-29 15:56:53 test/co/co-5586-T7-01598.jpg
# ?rw-r--r-- phunc20/wheel      21882 2020-09-29 16:05:42 test/co/co-5586-T6-07689.jpg
# ?rw-r--r-- phunc20/wheel       8982 2020-09-29 16:03:37 test/co/co-5586-T5-02810.jpg
# ?rw-r--r-- phunc20/wheel      48672 2020-09-29 15:57:05 test/co/co-5586-T7-09214.jpg
# ?rw-r--r-- phunc20/wheel      18131 2020-09-29 16:02:32 test/co/co-5586-T2-05150.jpg
# ?rw-r--r-- phunc20/wheel       6388 2020-09-29 15:59:11 test/co/co-5586-T8-06400.jpg
# ?rw-r--r-- phunc20/wheel      51880 2020-09-29 15:56:51 test/co/co-5586-T7-00238.jpg
# ?rw-r--r-- phunc20/wheel       9022 2020-09-29 16:03:45 test/co/co-5586-T5-08259.jpg
# ?rw-r--r-- phunc20/wheel       9235 2020-09-29 16:03:43 test/co/co-5586-T5-06334.jpg
# ?rw-r--r-- phunc20/wheel      22226 2020-09-29 16:05:34 test/co/co-5586-T6-03279.jpg
# ?rw-r--r-- phunc20/wheel      10749 2020-09-29 16:01:33 test/co/co-5586-T1-10563.jpg
# ?rw-r--r-- phunc20/wheel      17450 2020-09-29 16:02:29 test/co/co-5586-T2-03775.jpg
# ?rw-r--r-- phunc20/wheel       6460 2020-09-29 15:59:16 test/co/co-5586-T8-10284.jpg
# ?rw-r--r-- phunc20/wheel      43620 2020-09-29 15:56:12 test/co/co-5586-T3-03609.jpg
# ?rw-r--r-- phunc20/wheel       6191 2020-09-29 15:59:05 test/co/co-5586-T8-02260.jpg
# ?rw-r--r-- phunc20/wheel      21443 2020-09-29 16:05:43 test/co/co-5586-T6-08165.jpg
# ?rw-r--r-- phunc20/wheel      41849 2020-09-29 15:56:12 test/co/co-5586-T3-03486.jpg
# ?rw-r--r-- phunc20/wheel      10266 2020-09-29 16:01:31 test/co/co-5586-T1-09269.jpg
# ?rw-r--r-- phunc20/wheel       6779 2020-09-29 15:59:15 test/co/co-5586-T8-09342.jpg
# ?rw-r--r-- phunc20/wheel      10506 2020-09-29 16:01:30 test/co/co-5586-T1-08798.jpg
# ?rw-r--r-- phunc20/wheel      52575 2020-09-29 15:56:53 test/co/co-5586-T7-01290.jpg
# ?rw-r--r-- phunc20/wheel       6201 2020-09-29 15:59:16 test/co/co-5586-T8-10739.jpg
# ?rw-r--r-- phunc20/wheel      18125 2020-09-29 16:02:32 test/co/co-5586-T2-05046.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6d0e4defb6d2> in <module>
# ----> 1 test_tarfile.list()
#
# /usr/local/lib/python3.7/tarfile.py in list(self, verbose, members)
#    1879         if members is None:
#    1880             members = self
# -> 1881         for tarinfo in members:
#    1882             if verbose:
#    1883                 _safe_print(stat.filemode(tarinfo.mode))
#
# /usr/local/lib/python3.7/tarfile.py in __iter__(self)
#    2401                 tarinfo = self.members[index]
#    2402             elif not self._loaded:
# -> 2403                 tarinfo = self.next()
#    2404                 if not tarinfo:
#    2405                     self._loaded = True
#
# /usr/local/lib/python3.7/tarfile.py in next(self)
#    2277         # Advance the file pointer.
#    2278         if self.offset != self.fileobj.tell():
# -> 2279             self.fileobj.seek(self.offset - 1)
#    2280             if not self.fileobj.read(1):
#    2281                 raise ReadError("unexpected end of data")
#
# /usr/local/lib/python3.7/bz2.py in seek(self, offset, whence)
#     272         with self._lock:
#     273             self._check_can_seek()
# --> 274             return self._buffer.seek(offset, whence)
#     275
#     276     def tell(self):
#
# /usr/local/lib/python3.7/_compression.py in seek(self, offset, whence)
#     141         # Read and discard data until we reach the desired position.
#     142         while offset > 0:
# --> 143             data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#     144             if not data:
#     145                 break
#
# /usr/local/lib/python3.7/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# KeyboardInterrupt:

# %%
import time
import asyncio

# %%
for k in range(10, 1, -1):
    print(k)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
any([False, False, False])
# Out:
# False

# %%
any([False, False, True])
# Out:
# True

# %%
all([False, False, False])
# Out:
# False

# %%
all([False, False, True])
# Out:
# False

# %% [markdown]
# I don't quite like the `is_prime` function written by Sebastiaan, so I rewrote similar ones. Let's test their efficiency.

# %%
def is_prime1(k):
    return not any((k % i) == 0 for i in range(2, k))

def is_prime2(k):
    for i in range(2, k):
        if (k % i) == 0:
            return False
    return True

# %%
# %%timeit
is_prime1(int(1e10))
# Out:
# 1.67 µs ± 131 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
is_prime2(int(1e10))
# Out:
# 797 ns ± 34.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
is_prime = is_prime2

# %%
print(None)
# Out:
# None

# %%
def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

def main():
    biggest_prime_le(int(1e7))
    biggest_prime_le(100_000)
    biggest_prime_le(10_000)
    biggest_prime_le(1_000)


main()
# Out:
# (10000000) Finding...
# (10000000) Found 9999991
# (  100000) Finding...
# (  100000) Found 99991
# (   10000) Finding...
# (   10000) Found 9973
# (    1000) Finding...
# (    1000) Found 997

# %% [markdown]
# #### Sth interesting
# - The biggest prime $\le$ `1e7` is `9999991`
# - The biggest prime $\le$ `1e5` is `99991`
#
# Coincidence?

# %% [raw]
# biggest_prime_le(int(1e9))

# %% [markdown]
# ```
# (1000000000) Finding...
# (1000000000) Found 999999937
# ```

# %% [markdown]
# ## Little by little
# Let's carry the code little by little towards asynchronous code like Sebastiaan did in the video

# %% [markdown]
# ### 1st: adding `async` to `main()`

# %%
def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    biggest_prime_le(int(1e7))
    biggest_prime_le(100_000)
    biggest_prime_le(10_000)
    biggest_prime_le(1_000)


main()
# Out:
# <coroutine object main at 0x7f5fc05f90e0>

# %% [markdown]
# Like Sebastiaan said in the video, `async` functions are <b>not</b> supposed to be called like this.
# <br>
# Instead, they are either to be <b><code>await</code></b>ed or to be put inside an <code><b>event_loop</b></code>, as we will briefly see.

# %% [raw]
# loop.close()

# %%
def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    biggest_prime_le(int(1e7))
    biggest_prime_le(100_000)
    biggest_prime_le(10_000)
    biggest_prime_le(1_000)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages/traitlets/config/configurable.py:118: RuntimeWarning: coroutine 'main' was never awaited
#   return  [c.__name__ for c in reversed(cls.__mro__) if
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-4fe1f588e82f> in <module>
#      15
#      16 loop = asyncio.get_event_loop()
# ---> 17 loop.run_until_complete(main())
#      18 ## Normally we need the next line to close things up, but inside jupyter notebook: No.
#      19 #loop.close()
#
# /usr/local/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     561         """
#     562         self._check_closed()
# --> 563         self._check_runnung()
#     564
#     565         new_task = not futures.isfuture(future)
#
# /usr/local/lib/python3.7/asyncio/base_events.py in _check_runnung(self)
#     521     def _check_runnung(self):
#     522         if self.is_running():
# --> 523             raise RuntimeError('This event loop is already running')
#     524         if events._get_running_loop() is not None:
#     525             raise RuntimeError(
#
# RuntimeError: This event loop is already running

# %%
pip show tornado
# Out:
# Name: tornado
# Version: 6.0.4
# Summary: Tornado is a Python web framework and asynchronous networking library, originally developed at FriendFeed.
# Home-page: http://www.tornadoweb.org/
# Author: Facebook
# Author-email: python-tornado@googlegroups.com
# License: http://www.apache.org/licenses/LICENSE-2.0
# Location: /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages
# Requires:
# Required-by: terminado, notebook, jupyter-client, ipykernel
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### What happened? Why the behaviour is diff from in the video?
# The story was sth related to package versions and `jupyter`. In brief summary, as far as I understand,
# > `jupyter` itself runs an event loop and does not allow another event loop to be run in any of its cells
#
# Two solutions:
# - Use `nest_asyncio` like below
# - Downgrade `tornado` to `tornado==4.5.3`
#
# **cf.**
# - [https://stackoverflow.com/questions/46827007/runtimeerror-this-event-loop-is-already-running-in-python](https://stackoverflow.com/questions/46827007/runtimeerror-this-event-loop-is-already-running-in-python)
# - [https://medium.com/@vyshali.enukonda/how-to-get-around-runtimeerror-this-event-loop-is-already-running-3f26f67e762e](https://medium.com/@vyshali.enukonda/how-to-get-around-runtimeerror-this-event-loop-is-already-running-3f26f67e762e)
# - [https://stackoverflow.com/questions/53248431/asyncio-runtimeerror-this-event-loop-is-already-running/53525009](https://stackoverflow.com/questions/53248431/asyncio-runtimeerror-this-event-loop-is-already-running/53525009)

# %%
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages (1.4.1)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/phunc20/.virtualenvs/async-by-sebastiaan/bin/python -m pip install --upgrade pip' command.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    biggest_prime_le(int(1e7))
    biggest_prime_le(100_000)
    biggest_prime_le(10_000)
    biggest_prime_le(1_000)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# (10000000) Finding...
# (10000000) Found 9999991
# (  100000) Finding...
# (  100000) Found 99991
# (   10000) Finding...
# (   10000) Found 9973
# (    1000) Finding...
# (    1000) Found 997

# %% [markdown]
# Now, the code runs, but **not** asynchronously.
#
# Let's try to add `async` keyword before the function `biggest_prime_le()`.

# %%
async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    biggest_prime_le(int(1e7))
    biggest_prime_le(100_000)
    biggest_prime_le(10_000)
    biggest_prime_le(1_000)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: coroutine 'biggest_prime_le' was never awaited
#   # This is added back by InteractiveShellApp.init_path()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: coroutine 'biggest_prime_le' was never awaited
#   if sys.path[0] == '':
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: coroutine 'biggest_prime_le' was never awaited
#   del sys.path[0]
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /home/phunc20/.virtualenvs/async-by-sebastiaan/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: coroutine 'biggest_prime_le' was never awaited
#
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# To fix this, let's `await` those `biggest_prime_le()` inside `main()`.

# %%
async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    await biggest_prime_le(int(1e7))
    await biggest_prime_le(100_000)
    await biggest_prime_le(10_000)
    await biggest_prime_le(1_000)

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# (10000000) Finding...
# (10000000) Found 9999991
# (  100000) Finding...
# (  100000) Found 99991
# (   10000) Finding...
# (   10000) Found 9973
# (    1000) Finding...
# (    1000) Found 997

# %% [markdown]
# now, let's introduce a new term: **`asyncio.wait()`**

# %%
async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        time.sleep(0.01)
    return None

async def main():
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# (    1000) Finding...
# (    1000) Found 997
# (  100000) Finding...
# (  100000) Found 99991
# (10000000) Finding...
# (10000000) Found 9999991
# (   10000) Finding...
# (   10000) Found 9973

# %% [markdown]
# Now, this is <b>slightly asynchronous</b>: The order of <code>print</code>s is now different.

# %% [markdown]
# ### Conciously adding a point of suspension in our code
# <b><code>asyncio.sleep()</code></b> instead of <code>time.sleep()</code>

# %%
async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        await asyncio.sleep(0.01)
        #time.sleep(0.01)
    return None

async def main():
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# (    1000) Finding...
# (   10000) Finding...
# (10000000) Finding...
# (  100000) Finding...
# (    1000) Found 997
# (10000000) Found 9999991
# (  100000) Found 99991
# (   10000) Found 9973

# %% [markdown]
# **Note** how those `Finding...` are all printed out first this time.

# %% [markdown]
# ### Let's time it

# %%
# %%time

print("Asynchronous code (i.e. using async.sleep())")

async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        await asyncio.sleep(0.01)
        #time.sleep(0.01)
    return None

async def main():
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# Asynchronous code (i.e. using async.sleep())
# (   10000) Finding...
# (10000000) Finding...
# (  100000) Finding...
# (    1000) Finding...
# (    1000) Found 997
# (10000000) Found 9999991
# (  100000) Found 99991
# (   10000) Found 9973
# CPU times: user 716 ms, sys: 9.87 ms, total: 726 ms
# Wall time: 986 ms

# %%
# %%time

print("Synchronous code (i.e. using time.sleep())")

async def biggest_prime_le(n):
    print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            print(f"({n:8d}) Found {k}")
            return k
        #await asyncio.sleep(0.01)
        time.sleep(0.01)
    return None

async def main():
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# Synchronous code (i.e. using time.sleep())
# (  100000) Finding...
# (  100000) Found 99991
# (10000000) Finding...
# (10000000) Found 9999991
# (    1000) Finding...
# (    1000) Found 997
# (   10000) Finding...
# (   10000) Found 9973
# CPU times: user 781 ms, sys: 6.54 ms, total: 788 ms
# Wall time: 1.27 s

# %%
print("Asynchronous code (i.e. using async.sleep())")

async def biggest_prime_le(n):
    #print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            #print(f"({n:8d}) Found {k}")
            return k
        await asyncio.sleep(0.01)
        #time.sleep(0.01)
    return None

async def main():
    t0 = time.time()
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])
    t1 = time.time()
    print(f"Took {1000*(t1-t0)} ms")

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# Asynchronous code (i.e. using async.sleep())
# Took 971.7938899993896 ms

# %%
print("Synchronous code (i.e. using time.sleep())")

async def biggest_prime_le(n):
    #print(f"({n:8d}) Finding...")
    for k in range(n, 1, -1):
        if is_prime(k):
            #print(f"({n:8d}) Found {k}")
            return k
        #await asyncio.sleep(0.01)
        time.sleep(0.01)
    return None

async def main():
    t0 = time.time()
    await asyncio.wait([
          biggest_prime_le(int(1e7)),
          biggest_prime_le(100_000),
          biggest_prime_le(10_000),
          biggest_prime_le(1_000),
    ])
    t1 = time.time()
    print(f"Took {1000*(t1-t0)} ms")

loop = asyncio.get_event_loop()
loop.run_until_complete(main())
## Normally we need the next line to close things up, but inside jupyter notebook: No.
#loop.close()
# Out:
# Synchronous code (i.e. using time.sleep())
# Took 1202.3682594299316 ms
